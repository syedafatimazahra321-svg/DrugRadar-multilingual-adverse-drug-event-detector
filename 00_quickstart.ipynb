# %% [markdown]
# # DrugRadar — Notebook 00: Quickstart

# %% [markdown]
# ## Cell 1 — Installing required libraries

# %%
# %pip install -q datasets transformers torch scikit-learn sentencepiece openai streamlit plotly spacy accelerate
print("installed")

# %% [markdown]
# ## Cell 2 — Creating required folders

# %%
import os

folders = [
    "data/raw",
    "data/processed",
    "data/augmented",
    "models/checkpoints",
    "outputs/predictions",
    "outputs/reports"
]

for f in folders:
    os.makedirs(f, exist_ok=True)
    print(f" Created: {f}/")
print("\n all folders created!")

# %% [markdown]
# ## Cell 3 — Checking imports

# %%
import torch
import transformers
import datasets
import sklearn
import pandas as pd
import numpy as np
import plotly

print(f"torch         {torch.__version__}")
print(f"transformers  {transformers.__version__}")
print(f"datasets      {datasets.__version__}")
print(f"sklearn       {sklearn.__version__}")
print(f"pandas        {pd.__version__}")
print(f"plotly        {plotly.__version__}")
print("\nimports working!")
# Out:
# torch         2.10.0+cu128
# transformers  5.0.0
# datasets      4.0.0
# sklearn       1.6.1
# pandas        2.2.2
# plotly        5.24.1
#
# imports working!

# %% [markdown]
# ## Cell 5 — Test dataset access

# %%
from datasets import load_dataset

print("Testing connection to HuggingFace dataset...")

ds = load_dataset("ade-benchmark-corpus/ade_corpus_v2", "Ade_corpus_v2_classification")
print(f"\nDataset loaded successfully!")
print(f"Total rows: {len(ds['train'])}")
print(f"Columns: {ds['train'].column_names}")
print("\nwokring properly")
# Out:
# Testing connection to HuggingFace dataset...
#
# Dataset loaded successfully!
# Total rows: 23516
# Columns: ['text', 'label']
#
# wokring properly
